// %% [markdown]
// # Getting started — Java in Jupyter
//
// Use the **Java** kernel (IJava). In Lab: *Kernel → Change Kernel… → Java*.
//
// Cells behave like **JShell**: statements and expressions without a `main` method.
//
// ## Tips
//
// - `%classpath` can add jars or directories — see [IJava](https://github.com/SpencerPark/IJava).
// - Topic notebooks follow the same `linear/`, `nonlinear/`, and `search/` layout as the other DSA tracks.

// %%
record Point(int x, int y) {}

var p = new Point(3, 4);
System.out.println("Point: " + p);

// %%
// Two pointers on an array
int[] nums = {1, 2, 3, 4, 5};
int i = 0, j = nums.length - 1;
while (i < j) {
    System.out.println(nums[i] + " " + nums[j]);
    i++;
    j--;
}
