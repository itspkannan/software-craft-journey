// %% [markdown]
// # Tries (Prefix Trees) - Practice Questions
//
// Complete each function and run the test cases to verify your solution.

// %%
import java.util.*;
import java.util.stream.*;
import java.util.function.*;

/** Test helpers (assertions always checked; not dependent on -ea). */
final class T {
    static void eq(String m, int a, int b) { if (a != b) throw new AssertionError(m + ": " + a + " != " + b); }
    static void eq(String m, long a, long b) { if (a != b) throw new AssertionError(m + ": " + a + " != " + b); }
    static void eq(String m, boolean a, boolean b) { if (a != b) throw new AssertionError(m); }
    static void eq(String m, String a, String b) { if (!Objects.equals(a, b)) throw new AssertionError(m + ": " + a + " != " + b); }
    static void eq(String m, int[] a, int[] b) {
        if (!Arrays.equals(a, b)) throw new AssertionError(m + ": " + Arrays.toString(a) + " != " + Arrays.toString(b));
    }
    static void eq(String m, List<Integer> a, int[] b) { eq(m, ia(a), b); }
    static void eq(String m, double a, double b) { if (Double.compare(a, b) != 0) throw new AssertionError(m); }
    static void eq(String m, List<Integer> a, List<Integer> b) { if (!a.equals(b)) throw new AssertionError(m + ": " + a + " != " + b); }
    static void eq(String m, List<List<String>> a, List<List<String>> b) { if (!a.equals(b)) throw new AssertionError(m); }
    static void eq(String m, List<List<Integer>> a, List<List<Integer>> b) { if (!a.equals(b)) throw new AssertionError(m); }
    static void eqDeep(String m, Object a, Object b) { if (!Objects.deepEquals(a, b)) throw new AssertionError(m + ": " + a + " vs " + b); }
    static void isNull(String m, Object a) { if (a != null) throw new AssertionError(m); }
    static void isTrue(String m, boolean b) { if (!b) throw new AssertionError(m); }
    static List<Integer> il(int... xs) { return Arrays.stream(xs).boxed().toList(); }
    static int[] ia(List<Integer> xs) { return xs.stream().mapToInt(i -> i).toArray(); }
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * from typing import List
 */

// Source imports: from typing import List

// %% [markdown]
// ---
// ## Q1: Implement Trie (Prefix Tree)
//
// Implement a trie with insert, search, and startsWith methods.

// %%
/*
 * --- Original exercise specification (reference) ---
 * class Trie:
 *  """
 *  A trie (prefix tree) for string operations.
 *  """
 *  
 *  def __init__(self):
 *  # Your code here
 *  pass
 *  
 *  def insert(self, word: str) -> None:
 *  """Insert word into trie."""
 *  pass
 *  
 *  def search(self, word: str) -> bool:
 *  """Return True if word is in trie."""
 *  pass
 *  
 *  def startsWith(self, prefix: str) -> bool:
 *  """Return True if any word starts with prefix."""
 *  pass
 */

class Trie {
    Trie() {
        throw new UnsupportedOperationException();
    }
    Object insert(String word) {
        throw new UnsupportedOperationException();
    }
    boolean search(String word) {
        throw new UnsupportedOperationException();
    }
    boolean startsWith(String prefix) {
        throw new UnsupportedOperationException();
    }
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * trie = Trie()
 * trie.insert("apple")
 * assert trie.search("apple") == True, "Test 1 failed"
 * assert trie.search("app") == False, "Test 2 failed"
 * assert trie.startsWith("app") == True, "Test 3 failed"
 * trie.insert("app")
 * assert trie.search("app") == True, "Test 4 failed"
 * print("All tests passed!")
 */

var trie = Trie();
// expr: trie.insert('apple')
// assert: assert trie.search('apple') == True, 'Test 1 failed'
// assert: assert trie.search('app') == False, 'Test 2 failed'
// assert: assert trie.startsWith('app') == True, 'Test 3 failed'
// expr: trie.insert('app')
// assert: assert trie.search('app') == True, 'Test 4 failed'
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q2: Design Add and Search Words Data Structure
//
// Design a data structure that supports adding words and searching with '.' as wildcard.

// %%
/*
 * --- Original exercise specification (reference) ---
 * class WordDictionary:
 *  """
 *  Trie with wildcard search support.
 *  '.' can match any single character.
 *  """
 *  
 *  def __init__(self):
 *  # Your code here
 *  pass
 *  
 *  def addWord(self, word: str) -> None:
 *  """Add word to dictionary."""
 *  pass
 *  
 *  def search(self, word: str) -> bool:
 *  """Search for word (. matches any char)."""
 *  pass
 */

class WordDictionary {
    WordDictionary() {
        throw new UnsupportedOperationException();
    }
    Object addWord(String word) {
        throw new UnsupportedOperationException();
    }
    boolean search(String word) {
        throw new UnsupportedOperationException();
    }
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * wd = WordDictionary()
 * wd.addWord("bad")
 * wd.addWord("dad")
 * wd.addWord("mad")
 * assert wd.search("pad") == False, "Test 1 failed"
 * assert wd.search("bad") == True, "Test 2 failed"
 * assert wd.search(".ad") == True, "Test 3 failed"
 * assert wd.search("b..") == True, "Test 4 failed"
 * print("All tests passed!")
 */

var wd = WordDictionary();
// expr: wd.addWord('bad')
// expr: wd.addWord('dad')
// expr: wd.addWord('mad')
// assert: assert wd.search('pad') == False, 'Test 1 failed'
// assert: assert wd.search('bad') == True, 'Test 2 failed'
// assert: assert wd.search('.ad') == True, 'Test 3 failed'
// assert: assert wd.search('b..') == True, 'Test 4 failed'
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q3: Word Search II
//
// Given an m x n board of characters and a list of words, return all words found on the board.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def find_words(board: List[List[str]], words: List[str]) -> List[str]:
 *  """
 *  Find all words from dictionary in board.
 *  
 *  Args:
 *  board: Character grid
 *  words: List of words to find
 *  
 *  Returns:
 *  List of found words
 *  """
 *  # Your code here
 *  pass
 */

static List<String> findWords(List<List<String>> board, List<String> words) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * board = [
 *  ["o","a","a","n"],
 *  ["e","t","a","e"],
 *  ["i","h","k","r"],
 *  ["i","f","l","v"]
 * ]
 * words = ["oath","pea","eat","rain"]
 * result = find_words(board, words)
 * assert set(result) == {"eat", "oath"}, f"Test 1 failed: {result}"
 * 
 * board = [["a","b"],["c","d"]]
 * words = ["abcb"]
 * assert find_words(board, words) == [], "Test 2 failed"
 * print("All tests passed!")
 */

// board = [['o', 'a', 'a', 'n'], ['e', 't', 'a', 'e'], ['i', 'h', 'k', 'r'], ['i', 'f', 'l', 'v']]  → implement in Java
// words = ['oath', 'pea', 'eat', 'rain']  → implement in Java
var result = findWords(board, words);
// assert: assert set(result) == {'eat', 'oath'}, f'Test 1 failed: {result}'
// board = [['a', 'b'], ['c', 'd']]  → implement in Java
// words = ['abcb']  → implement in Java
T.eqDeep("Test 2 failed", findWords(board, words), Arrays.asList());
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q4: Replace Words
//
// Given a dictionary of root words and a sentence, replace words with their root.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def replace_words(dictionary: List[str], sentence: str) -> str:
 *  """
 *  Replace words with shortest root from dictionary.
 *  
 *  Args:
 *  dictionary: List of root words
 *  sentence: Input sentence
 *  
 *  Returns:
 *  Sentence with words replaced by roots
 *  """
 *  # Your code here
 *  pass
 */

static String replaceWords(List<String> dictionary, String sentence) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * dictionary = ["cat","bat","rat"]
 * sentence = "the cattle was rattled by the battery"
 * assert replace_words(dictionary, sentence) == "the cat was rat by the bat", "Test 1 failed"
 * 
 * dictionary = ["a","b","c"]
 * sentence = "aadsfasf absbs bbab cadsfabd"
 * assert replace_words(dictionary, sentence) == "a]\n a b c", "Test 2 failed"
 * print("All tests passed!")
 */

// dictionary = ['cat', 'bat', 'rat']  → implement in Java
// sentence = 'the cattle was rattled by the battery'  → implement in Java
T.eq("Test 1 failed", replaceWords(dictionary, sentence), "the cat was rat by the bat");
// dictionary = ['a', 'b', 'c']  → implement in Java
// sentence = 'aadsfasf absbs bbab cadsfabd'  → implement in Java
T.eq("Test 2 failed", replaceWords(dictionary, sentence), "a]\n a b c");
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q5: Longest Word in Dictionary
//
// Given an array of words, find the longest word that can be built one character at a time by other words.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def longest_word(words: List[str]) -> str:
 *  """
 *  Find longest word buildable character by character.
 *  
 *  Args:
 *  words: List of words
 *  
 *  Returns:
 *  Longest buildable word (lexicographically smallest if tie)
 *  """
 *  # Your code here
 *  pass
 */

static String longestWord(List<String> words) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert longest_word(["w","wo","wor","worl","world"]) == "world", "Test 1 failed"
 * assert longest_word(["a","banana","app","appl","ap","apply","apple"]) == "apple", "Test 2 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", longestWord(Arrays.asList("w", "wo", "wor", "worl", "world")), "world");
T.eq("Test 2 failed", longestWord(Arrays.asList("a", "banana", "app", "appl", "ap", "apply", "apple")), "apple");
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q6: Implement Magic Dictionary
//
// Design a data structure that supports finding if a word can match by changing exactly one character.

// %%
/*
 * --- Original exercise specification (reference) ---
 * class MagicDictionary:
 *  """
 *  Dictionary where search matches with exactly one char changed.
 *  """
 *  
 *  def __init__(self):
 *  # Your code here
 *  pass
 *  
 *  def buildDict(self, dictionary: List[str]) -> None:
 *  """Build dictionary from list of words."""
 *  pass
 *  
 *  def search(self, searchWord: str) -> bool:
 *  """Return True if word matches by changing exactly one char."""
 *  pass
 */

class MagicDictionary {
    MagicDictionary() {
        throw new UnsupportedOperationException();
    }
    Object buildDict(List<String> dictionary) {
        throw new UnsupportedOperationException();
    }
    boolean search(String searchWord) {
        throw new UnsupportedOperationException();
    }
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * md = MagicDictionary()
 * md.buildDict(["hello", "leetcode"])
 * assert md.search("hello") == False, "Test 1 failed" # No change
 * assert md.search("hhllo") == True, "Test 2 failed" # One char different
 * assert md.search("hell") == False, "Test 3 failed" # Different length
 * assert md.search("leetcoded") == False, "Test 4 failed"
 * print("All tests passed!")
 */

var md = MagicDictionary();
// expr: md.buildDict(['hello', 'leetcode'])
// assert: assert md.search('hello') == False, 'Test 1 failed'
// assert: assert md.search('hhllo') == True, 'Test 2 failed'
// assert: assert md.search('hell') == False, 'Test 3 failed'
// assert: assert md.search('leetcoded') == False, 'Test 4 failed'
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q7: Stream of Characters
//
// Implement a StreamChecker class that checks if a suffix of the stream matches any word.

// %%
/*
 * --- Original exercise specification (reference) ---
 * class StreamChecker:
 *  """
 *  Check if stream suffix matches any dictionary word.
 *  """
 *  
 *  def __init__(self, words: List[str]):
 *  # Your code here
 *  pass
 *  
 *  def query(self, letter: str) -> bool:
 *  """Add letter and check if suffix matches any word."""
 *  pass
 */

class StreamChecker {
    StreamChecker(List<String> words) {
        throw new UnsupportedOperationException();
    }
    boolean query(String letter) {
        throw new UnsupportedOperationException();
    }
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * sc = StreamChecker(["cd", "f", "kl"])
 * assert sc.query('a') == False, "Test 1 failed"
 * assert sc.query('b') == False, "Test 2 failed"
 * assert sc.query('c') == False, "Test 3 failed"
 * assert sc.query('d') == True, "Test 4 failed" # "cd" found
 * assert sc.query('e') == False, "Test 5 failed"
 * assert sc.query('f') == True, "Test 6 failed" # "f" found
 * print("All tests passed!")
 */

var sc = StreamChecker(Arrays.asList("cd", "f", "kl"));
// assert: assert sc.query('a') == False, 'Test 1 failed'
// assert: assert sc.query('b') == False, 'Test 2 failed'
// assert: assert sc.query('c') == False, 'Test 3 failed'
// assert: assert sc.query('d') == True, 'Test 4 failed'
// assert: assert sc.query('e') == False, 'Test 5 failed'
// assert: assert sc.query('f') == True, 'Test 6 failed'
System.out.println("All tests passed!");
