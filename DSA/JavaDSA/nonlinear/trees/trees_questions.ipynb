// %% [markdown]
// # Trees - Practice Questions
//
// Complete each function and run the test cases to verify your solution.

// %%
import java.util.*;
import java.util.stream.*;
import java.util.function.*;

/** Test helpers (assertions always checked; not dependent on -ea). */
final class T {
    static void eq(String m, int a, int b) { if (a != b) throw new AssertionError(m + ": " + a + " != " + b); }
    static void eq(String m, long a, long b) { if (a != b) throw new AssertionError(m + ": " + a + " != " + b); }
    static void eq(String m, boolean a, boolean b) { if (a != b) throw new AssertionError(m); }
    static void eq(String m, String a, String b) { if (!Objects.equals(a, b)) throw new AssertionError(m + ": " + a + " != " + b); }
    static void eq(String m, int[] a, int[] b) {
        if (!Arrays.equals(a, b)) throw new AssertionError(m + ": " + Arrays.toString(a) + " != " + Arrays.toString(b));
    }
    static void eq(String m, List<Integer> a, int[] b) { eq(m, ia(a), b); }
    static void eq(String m, double a, double b) { if (Double.compare(a, b) != 0) throw new AssertionError(m); }
    static void eq(String m, List<Integer> a, List<Integer> b) { if (!a.equals(b)) throw new AssertionError(m + ": " + a + " != " + b); }
    static void eq(String m, List<List<String>> a, List<List<String>> b) { if (!a.equals(b)) throw new AssertionError(m); }
    static void eq(String m, List<List<Integer>> a, List<List<Integer>> b) { if (!a.equals(b)) throw new AssertionError(m); }
    static void eqDeep(String m, Object a, Object b) { if (!Objects.deepEquals(a, b)) throw new AssertionError(m + ": " + a + " vs " + b); }
    static void isNull(String m, Object a) { if (a != null) throw new AssertionError(m); }
    static void isTrue(String m, boolean b) { if (!b) throw new AssertionError(m); }
    static List<Integer> il(int... xs) { return Arrays.stream(xs).boxed().toList(); }
    static int[] ia(List<Integer> xs) { return xs.stream().mapToInt(i -> i).toArray(); }
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Tree Node and Helper Functions
 * from collections import deque
 * from typing import Optional, List
 * 
 * class TreeNode:
 *  def __init__(self, val=0, left=None, right=None):
 *  self.val = val
 *  self.left = left
 *  self.right = right
 * 
 * def build_tree(vals: list) -> Optional[TreeNode]:
 *  """Build tree from level-order list. None represents missing node."""
 *  if not vals or vals[0] is None:
 *  return None
 *  root = TreeNode(vals[0])
 *  queue = deque([root])
 *  i = 1
 *  while queue and i < len(vals):
 *  node = queue.popleft()
 *  if i < len(vals) and vals[i] is not None:
 *  node.left = TreeNode(vals[i])
 *  queue.append(node.left)
 *  i += 1
 *  if i < len(vals) and vals[i] is not None:
 *  node.right = TreeNode(vals[i])
 *  queue.append(node.right)
 *  i += 1
 *  return root
 * 
 * def tree_to_list(root: TreeNode) -> list:
 *  """Convert tree to level-order list for testing."""
 *  if not root:
 *  return []
 *  result = []
 *  queue = deque([root])
 *  while queue:
 *  node = queue.popleft()
 *  if node:
 *  result.append(node.val)
 *  queue.append(node.left)
 *  queue.append(node.right)
 *  else:
 *  result.append(None)
 *  while result and result[-1] is None:
 *  result.pop()
 *  return result
 */

// Source imports: from collections import deque
// Source imports: from typing import Optional, List
class TreeNode {
    int val;
    TreeNode left, right;
    TreeNode() { this(0, null, null); }
    TreeNode(int val) { this(val, null, null); }
    TreeNode(int val, TreeNode left, TreeNode right) {
        this.val = val;
        this.left = left;
        this.right = right;
    }
}

static TreeNode buildTree(List<Integer> vals) {
    // TODO: implement from specification above
}
static List<Integer> treeToList(TreeNode root) {
    // TODO: implement from specification above
}

// %% [markdown]
// ---
// ## Q1: Maximum Depth of Binary Tree
//
// Given the root of a binary tree, return its maximum depth.
//
// Maximum depth is the number of nodes along the longest path from root to leaf.

// %%
/*
 * --- Original exercise specification (reference) ---
 * from typing import Optional
 * 
 * def max_depth(root: Optional[TreeNode]) -> int:
 *  """
 *  Find maximum depth of binary tree.
 *  
 *  Args:
 *  root: Root of binary tree
 *  
 *  Returns:
 *  Maximum depth (number of nodes on longest path)
 *  """
 *  # Your code here
 *  pass
 */

// Source imports: from typing import Optional
static int maxDepth(TreeNode root) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert max_depth(build_tree([3, 9, 20, None, None, 15, 7])) == 3, "Test 1 failed"
 * assert max_depth(build_tree([1, None, 2])) == 2, "Test 2 failed"
 * assert max_depth(None) == 0, "Test 3 failed"
 * assert max_depth(build_tree([1])) == 1, "Test 4 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", maxDepth(buildTree(Arrays.asList(3, 9, 20, null, null, 15, 7))), 3);
T.eq("Test 2 failed", maxDepth(buildTree(Arrays.asList(1, null, 2))), 2);
T.eq("Test 3 failed", maxDepth(null), 0);
T.eq("Test 4 failed", maxDepth(buildTree(java.util.Arrays.stream(new int[] {1}).boxed().toList())), 1);
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q2: Invert Binary Tree
//
// Given the root of a binary tree, invert the tree (mirror image), and return its root.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def invert_tree(root: Optional[TreeNode]) -> Optional[TreeNode]:
 *  """
 *  Invert binary tree (mirror image).
 *  
 *  Args:
 *  root: Root of binary tree
 *  
 *  Returns:
 *  Root of inverted tree
 *  """
 *  # Your code here
 *  pass
 */

static TreeNode invertTree(TreeNode root) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * result = invert_tree(build_tree([4, 2, 7, 1, 3, 6, 9]))
 * assert tree_to_list(result) == [4, 7, 2, 9, 6, 3, 1], "Test 1 failed"
 * 
 * result = invert_tree(build_tree([2, 1, 3]))
 * assert tree_to_list(result) == [2, 3, 1], "Test 2 failed"
 * 
 * assert invert_tree(None) is None, "Test 3 failed"
 * print("All tests passed!")
 */

var result = invertTree(buildTree(java.util.Arrays.stream(new int[] {4, 2, 7, 1, 3, 6, 9}).boxed().toList()));
T.eq("Test 1 failed", treeToList(result), new int[] {4, 7, 2, 9, 6, 3, 1});
result = invertTree(buildTree(java.util.Arrays.stream(new int[] {2, 1, 3}).boxed().toList()));
T.eq("Test 2 failed", treeToList(result), new int[] {2, 3, 1});
T.isNull("Test 3 failed", invertTree(null));
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q3: Same Tree
//
// Given the roots of two binary trees, check if they are the same (structurally identical with same values).

// %%
/*
 * --- Original exercise specification (reference) ---
 * def is_same_tree(p: Optional[TreeNode], q: Optional[TreeNode]) -> bool:
 *  """
 *  Check if two trees are identical.
 *  
 *  Args:
 *  p: Root of first tree
 *  q: Root of second tree
 *  
 *  Returns:
 *  True if trees are identical
 *  """
 *  # Your code here
 *  pass
 */

static boolean isSameTree(TreeNode p, TreeNode q) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * p = build_tree([1, 2, 3])
 * q = build_tree([1, 2, 3])
 * assert is_same_tree(p, q) == True, "Test 1 failed"
 * 
 * p = build_tree([1, 2])
 * q = build_tree([1, None, 2])
 * assert is_same_tree(p, q) == False, "Test 2 failed"
 * 
 * assert is_same_tree(None, None) == True, "Test 3 failed"
 * print("All tests passed!")
 */

var p = buildTree(java.util.Arrays.stream(new int[] {1, 2, 3}).boxed().toList());
var q = buildTree(java.util.Arrays.stream(new int[] {1, 2, 3}).boxed().toList());
T.eq("Test 1 failed", isSameTree(p, q), true);
p = buildTree(java.util.Arrays.stream(new int[] {1, 2}).boxed().toList());
q = buildTree(Arrays.asList(1, null, 2));
T.eq("Test 2 failed", isSameTree(p, q), false);
T.eq("Test 3 failed", isSameTree(null, null), true);
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q4: Symmetric Tree
//
// Given the root of a binary tree, check whether it is a mirror of itself (symmetric around its center).

// %%
/*
 * --- Original exercise specification (reference) ---
 * def is_symmetric(root: Optional[TreeNode]) -> bool:
 *  """
 *  Check if tree is symmetric (mirror of itself).
 *  
 *  Args:
 *  root: Root of binary tree
 *  
 *  Returns:
 *  True if symmetric
 *  """
 *  # Your code here
 *  pass
 */

static boolean isSymmetric(TreeNode root) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert is_symmetric(build_tree([1, 2, 2, 3, 4, 4, 3])) == True, "Test 1 failed"
 * assert is_symmetric(build_tree([1, 2, 2, None, 3, None, 3])) == False, "Test 2 failed"
 * assert is_symmetric(build_tree([1])) == True, "Test 3 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", isSymmetric(buildTree(java.util.Arrays.stream(new int[] {1, 2, 2, 3, 4, 4, 3}).boxed().toList())), true);
T.eq("Test 2 failed", isSymmetric(buildTree(Arrays.asList(1, 2, 2, null, 3, null, 3))), false);
T.eq("Test 3 failed", isSymmetric(buildTree(java.util.Arrays.stream(new int[] {1}).boxed().toList())), true);
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q5: Validate Binary Search Tree
//
// Given the root of a binary tree, determine if it is a valid BST.
//
// A valid BST:
// - Left subtree contains only nodes with keys **less than** the node's key
// - Right subtree contains only nodes with keys **greater than** the node's key
// - Both subtrees are also valid BSTs

// %%
/*
 * --- Original exercise specification (reference) ---
 * def is_valid_bst(root: Optional[TreeNode]) -> bool:
 *  """
 *  Check if tree is a valid BST.
 *  
 *  Args:
 *  root: Root of binary tree
 *  
 *  Returns:
 *  True if valid BST
 *  """
 *  # Your code here
 *  pass
 */

static boolean isValidBst(TreeNode root) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert is_valid_bst(build_tree([2, 1, 3])) == True, "Test 1 failed"
 * assert is_valid_bst(build_tree([5, 1, 4, None, None, 3, 6])) == False, "Test 2 failed"
 * assert is_valid_bst(build_tree([5, 4, 6, None, None, 3, 7])) == False, "Test 3 failed" # 3 < 5
 * print("All tests passed!")
 */

T.eq("Test 1 failed", isValidBst(buildTree(java.util.Arrays.stream(new int[] {2, 1, 3}).boxed().toList())), true);
T.eq("Test 2 failed", isValidBst(buildTree(Arrays.asList(5, 1, 4, null, null, 3, 6))), false);
T.eq("Test 3 failed", isValidBst(buildTree(Arrays.asList(5, 4, 6, null, null, 3, 7))), false);
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q6: Binary Tree Level Order Traversal
//
// Given the root of a binary tree, return the level order traversal of its nodes' values (left to right, level by level).

// %%
/*
 * --- Original exercise specification (reference) ---
 * def level_order(root: Optional[TreeNode]) -> List[List[int]]:
 *  """
 *  Return level order traversal.
 *  
 *  Args:
 *  root: Root of binary tree
 *  
 *  Returns:
 *  List of lists, each containing values at that level
 *  """
 *  pass
 */

static List<List<Integer>> levelOrder(TreeNode root) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert level_order(build_tree([3, 9, 20, None, None, 15, 7])) == [[3], [9, 20], [15, 7]], "Test 1 failed"
 * assert level_order(build_tree([1])) == [[1]], "Test 2 failed"
 * assert level_order(None) == [], "Test 3 failed"
 * print("All tests passed!")
 */

T.eqDeep("Test 1 failed", levelOrder(buildTree(Arrays.asList(3, 9, 20, null, null, 15, 7))), Arrays.asList(new int[] {3}, new int[] {9, 20}, new int[] {15, 7}));
T.eqDeep("Test 2 failed", levelOrder(buildTree(java.util.Arrays.stream(new int[] {1}).boxed().toList())), Arrays.asList(new int[] {1}));
T.eqDeep("Test 3 failed", levelOrder(null), Arrays.asList());
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q7: Lowest Common Ancestor of a Binary Tree
//
// Given a binary tree, find the lowest common ancestor (LCA) of two given nodes.
//
// The LCA is the lowest node that has both p and q as descendants (a node can be a descendant of itself).

// %%
/*
 * --- Original exercise specification (reference) ---
 * def lowest_common_ancestor(root: TreeNode, p: TreeNode, q: TreeNode) -> TreeNode:
 *  """
 *  Find lowest common ancestor of p and q.
 *  
 *  Args:
 *  root: Root of tree
 *  p: First node
 *  q: Second node
 *  
 *  Returns:
 *  LCA node
 *  """
 *  # Your code here
 *  pass
 */

static TreeNode lowestCommonAncestor(TreeNode root, TreeNode p, TreeNode q) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * root = build_tree([3, 5, 1, 6, 2, 0, 8, None, None, 7, 4])
 * p = root.left # node 5
 * q = root.right # node 1
 * assert lowest_common_ancestor(root, p, q).val == 3, "Test 1 failed"
 * 
 * p = root.left # node 5
 * q = root.left.right.right # node 4
 * assert lowest_common_ancestor(root, p, q).val == 5, "Test 2 failed"
 * print("All tests passed!")
 */

var root = buildTree(Arrays.asList(3, 5, 1, 6, 2, 0, 8, null, null, 7, 4));
// p = root.left  → implement in Java
// q = root.right  → implement in Java
// assert: assert lowest_common_ancestor(root, p, q).val == 3, 'Test 1 failed'
// p = root.left  → implement in Java
// q = root.left.right.right  → implement in Java
// assert: assert lowest_common_ancestor(root, p, q).val == 5, 'Test 2 failed'
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q8: Binary Tree Right Side View
//
// Given the root of a binary tree, imagine yourself standing on the right side. Return the values of the nodes you can see ordered from top to bottom.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def right_side_view(root: Optional[TreeNode]) -> List[int]:
 *  """
 *  Return right side view of tree.
 *  
 *  Args:
 *  root: Root of binary tree
 *  
 *  Returns:
 *  List of visible node values from right side
 *  """
 *  # Your code here
 *  pass
 */

static List<Integer> rightSideView(TreeNode root) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert right_side_view(build_tree([1, 2, 3, None, 5, None, 4])) == [1, 3, 4], "Test 1 failed"
 * assert right_side_view(build_tree([1, None, 3])) == [1, 3], "Test 2 failed"
 * assert right_side_view(None) == [], "Test 3 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", rightSideView(buildTree(Arrays.asList(1, 2, 3, null, 5, null, 4))), new int[] {1, 3, 4});
T.eq("Test 2 failed", rightSideView(buildTree(Arrays.asList(1, null, 3))), new int[] {1, 3});
T.eqDeep("Test 3 failed", rightSideView(null), Arrays.asList());
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q9: Serialize and Deserialize Binary Tree
//
// Design an algorithm to serialize and deserialize a binary tree.
//
// Serialization is converting a tree to a string. Deserialization is reconstructing the tree from the string.

// %%
/*
 * --- Original exercise specification (reference) ---
 * class Codec:
 *  def serialize(self, root: Optional[TreeNode]) -> str:
 *  """Encodes a tree to a single string."""
 *  # Your code here
 *  pass
 *  
 *  def deserialize(self, data: str) -> Optional[TreeNode]:
 *  """Decodes your encoded data to tree."""
 *  # Your code here
 *  pass
 */

class Codec {
    String serialize(TreeNode root) {
        throw new UnsupportedOperationException();
    }
    TreeNode deserialize(String data) {
        throw new UnsupportedOperationException();
    }
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * codec = Codec()
 * root = build_tree([1, 2, 3, None, None, 4, 5])
 * serialized = codec.serialize(root)
 * deserialized = codec.deserialize(serialized)
 * assert tree_to_list(deserialized) == [1, 2, 3, None, None, 4, 5], "Test 1 failed"
 * 
 * assert codec.deserialize(codec.serialize(None)) is None, "Test 2 failed"
 * print("All tests passed!")
 */

var codec = Codec();
var root = buildTree(Arrays.asList(1, 2, 3, null, null, 4, 5));
// serialized = codec.serialize(root)  → implement in Java
// deserialized = codec.deserialize(serialized)  → implement in Java
T.eqDeep("Test 1 failed", treeToList(deserialized), Arrays.asList(1, 2, 3, null, null, 4, 5));
// assert: assert codec.deserialize(codec.serialize(None)) is None, 'Test 2 failed'
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q10: Kth Smallest Element in a BST
//
// Given the root of a BST and an integer k, return the kth smallest value (1-indexed) of all nodes in the tree.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def kth_smallest(root: Optional[TreeNode], k: int) -> int:
 *  """
 *  Find kth smallest element in BST.
 *  
 *  Args:
 *  root: Root of BST
 *  k: Position (1-indexed)
 *  
 *  Returns:
 *  kth smallest value
 *  """
 *  # Your code here
 *  pass
 */

static int kthSmallest(TreeNode root, int k) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert kth_smallest(build_tree([3, 1, 4, None, 2]), 1) == 1, "Test 1 failed"
 * assert kth_smallest(build_tree([5, 3, 6, 2, 4, None, None, 1]), 3) == 3, "Test 2 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", kthSmallest(buildTree(Arrays.asList(3, 1, 4, null, 2)), 1), 1);
T.eq("Test 2 failed", kthSmallest(buildTree(Arrays.asList(5, 3, 6, 2, 4, null, null, 1)), 3), 3);
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q11: Kth Largest Element in a BST
//
// Given the root of a BST and an integer k, return the kth largest value (1-indexed) of all nodes in the tree.
//
// **Note**: This is the reverse of kth smallest - think about how BST properties can help.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def kth_largest(root: Optional[TreeNode], k: int) -> int:
 *  """
 *  Find kth largest element in BST.
 *  
 *  Args:
 *  root: Root of BST
 *  k: Position (1-indexed)
 *  
 *  Returns:
 *  kth largest value
 *  """
 *  # Your code here
 *  pass
 */

static int kthLargest(TreeNode root, int k) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert kth_largest(build_tree([3, 1, 4, None, 2]), 1) == 4, "Test 1 failed" # Largest
 * assert kth_largest(build_tree([5, 3, 6, 2, 4, None, None, 1]), 2) == 5, "Test 2 failed" # 2nd largest
 * assert kth_largest(build_tree([5, 3, 6, 2, 4, None, None, 1]), 4) == 3, "Test 3 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", kthLargest(buildTree(Arrays.asList(3, 1, 4, null, 2)), 1), 4);
T.eq("Test 2 failed", kthLargest(buildTree(Arrays.asList(5, 3, 6, 2, 4, null, null, 1)), 2), 5);
T.eq("Test 3 failed", kthLargest(buildTree(Arrays.asList(5, 3, 6, 2, 4, null, null, 1)), 4), 3);
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q12: Path Sum
//
// Given the root of a binary tree and an integer targetSum, return true if the tree has a **root-to-leaf** path such that adding up all the values along the path equals targetSum.
//
// A **leaf** is a node with no children.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def has_path_sum(root: Optional[TreeNode], targetSum: int) -> bool:
 *  """
 *  Check if tree has root-to-leaf path with given sum.
 *  
 *  Args:
 *  root: Root of binary tree
 *  targetSum: Target sum to find
 *  
 *  Returns:
 *  True if path exists with target sum
 *  """
 *  # Your code here
 *  pass
 */

static boolean hasPathSum(TreeNode root, int targetSum) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * # 5
 * # / \
 * # 4 8
 * # / / \
 * # 11 13 4
 * # / \ \
 * # 7 2 1
 * root = build_tree([5, 4, 8, 11, None, 13, 4, 7, 2, None, None, None, 1])
 * assert has_path_sum(root, 22) == True, "Test 1 failed" # 5->4->11->2
 * assert has_path_sum(root, 26) == True, "Test 2 failed" # 5->8->13
 * assert has_path_sum(root, 18) == True, "Test 3 failed" # 5->8->4->1
 * assert has_path_sum(root, 10) == False, "Test 4 failed"
 * 
 * assert has_path_sum(build_tree([1, 2, 3]), 5) == False, "Test 5 failed"
 * assert has_path_sum(None, 0) == False, "Test 6 failed"
 * print("All tests passed!")
 */

var root = buildTree(Arrays.asList(5, 4, 8, 11, null, 13, 4, 7, 2, null, null, null, 1));
T.eq("Test 1 failed", hasPathSum(root, 22), true);
T.eq("Test 2 failed", hasPathSum(root, 26), true);
T.eq("Test 3 failed", hasPathSum(root, 18), true);
T.eq("Test 4 failed", hasPathSum(root, 10), false);
T.eq("Test 5 failed", hasPathSum(buildTree(java.util.Arrays.stream(new int[] {1, 2, 3}).boxed().toList()), 5), false);
T.eq("Test 6 failed", hasPathSum(null, 0), false);
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q13: Path Sum II - Return the Path
//
// Given the root of a binary tree and an integer targetSum, return **the path** (as a list of node values) from root to leaf where the sum equals targetSum.
//
// If no such path exists, return an empty list. If multiple paths exist, return any one of them.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def path_sum_return_path(root: Optional[TreeNode], targetSum: int) -> List[int]:
 *  """
 *  Find a root-to-leaf path with given sum and return the path.
 *  
 *  Args:
 *  root: Root of binary tree
 *  targetSum: Target sum to find
 *  
 *  Returns:
 *  List of node values forming the path, or empty list if not found
 *  """
 *  # Your code here
 *  pass
 */

static List<Integer> pathSumReturnPath(TreeNode root, int targetSum) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * # 5
 * # / \
 * # 4 8
 * # / / \
 * # 11 13 4
 * # / \ \
 * # 7 2 1
 * root = build_tree([5, 4, 8, 11, None, 13, 4, 7, 2, None, None, None, 1])
 * 
 * path = path_sum_return_path(root, 22)
 * assert path == [5, 4, 11, 2], f"Test 1 failed: {path}" # 5->4->11->2
 * 
 * path = path_sum_return_path(root, 26)
 * assert path == [5, 8, 13], f"Test 2 failed: {path}" # 5->8->13
 * 
 * path = path_sum_return_path(root, 100)
 * assert path == [], f"Test 3 failed: {path}" # No path
 * 
 * assert path_sum_return_path(None, 0) == [], "Test 4 failed"
 * print("All tests passed!")
 */

var root = buildTree(Arrays.asList(5, 4, 8, 11, null, 13, 4, 7, 2, null, null, null, 1));
var path = pathSumReturnPath(root, 22);
// assert: assert path == [5, 4, 11, 2], f'Test 1 failed: {path}'
path = pathSumReturnPath(root, 26);
// assert: assert path == [5, 8, 13], f'Test 2 failed: {path}'
path = pathSumReturnPath(root, 100);
// assert: assert path == [], f'Test 3 failed: {path}'
T.eqDeep("Test 4 failed", pathSumReturnPath(null, 0), Arrays.asList());
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q14: Path Sum III - Return All Paths
//
// Given the root of a binary tree and an integer targetSum, return **all root-to-leaf paths** where the sum of node values equals targetSum.
//
// Return a list of lists, where each inner list represents a valid path.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def path_sum_all_paths(root: Optional[TreeNode], targetSum: int) -> List[List[int]]:
 *  """
 *  Find all root-to-leaf paths with given sum.
 *  
 *  Args:
 *  root: Root of binary tree
 *  targetSum: Target sum to find
 *  
 *  Returns:
 *  List of all valid paths (each path is a list of node values)
 *  """
 *  # Your code here
 *  pass
 */

static List<List<Integer>> pathSumAllPaths(TreeNode root, int targetSum) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * # 5
 * # / \
 * # 4 8
 * # / / \
 * # 11 13 4
 * # / \ / \
 * # 7 2 5 1
 * root = build_tree([5, 4, 8, 11, None, 13, 4, 7, 2, None, None, 5, 1])
 * 
 * paths = path_sum_all_paths(root, 22)
 * # Two valid paths: [5,4,11,2] and [5,8,4,5]
 * assert len(paths) == 2, f"Test 1 failed: expected 2 paths, got {len(paths)}"
 * assert [5, 4, 11, 2] in paths, f"Test 1 failed: missing [5,4,11,2]"
 * assert [5, 8, 4, 5] in paths, f"Test 1 failed: missing [5,8,4,5]"
 * 
 * paths = path_sum_all_paths(root, 26)
 * assert paths == [[5, 8, 13]], f"Test 2 failed: {paths}"
 * 
 * paths = path_sum_all_paths(root, 100)
 * assert paths == [], f"Test 3 failed: {paths}"
 * 
 * assert path_sum_all_paths(None, 0) == [], "Test 4 failed"
 * print("All tests passed!")
 */

var root = buildTree(Arrays.asList(5, 4, 8, 11, null, 13, 4, 7, 2, null, null, 5, 1));
var paths = pathSumAllPaths(root, 22);
T.eq("assert failed", len(paths), 2);
// assert: assert [5, 4, 11, 2] in paths, f'Test 1 failed: missing [5,4,11,2]'
// assert: assert [5, 8, 4, 5] in paths, f'Test 1 failed: missing [5,8,4,5]'
paths = pathSumAllPaths(root, 26);
// assert: assert paths == [[5, 8, 13]], f'Test 2 failed: {paths}'
paths = pathSumAllPaths(root, 100);
// assert: assert paths == [], f'Test 3 failed: {paths}'
T.eqDeep("Test 4 failed", pathSumAllPaths(null, 0), Arrays.asList());
System.out.println("All tests passed!");
