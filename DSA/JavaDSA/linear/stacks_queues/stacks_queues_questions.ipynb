// %% [markdown]
// # Stacks and Queues - Practice Questions
//
// Complete each function and run the test cases to verify your solution.

// %%
import java.util.*;
import java.util.stream.*;
import java.util.function.*;

/** Test helpers (assertions always checked; not dependent on -ea). */
final class T {
    static void eq(String m, int a, int b) { if (a != b) throw new AssertionError(m + ": " + a + " != " + b); }
    static void eq(String m, long a, long b) { if (a != b) throw new AssertionError(m + ": " + a + " != " + b); }
    static void eq(String m, boolean a, boolean b) { if (a != b) throw new AssertionError(m); }
    static void eq(String m, String a, String b) { if (!Objects.equals(a, b)) throw new AssertionError(m + ": " + a + " != " + b); }
    static void eq(String m, int[] a, int[] b) {
        if (!Arrays.equals(a, b)) throw new AssertionError(m + ": " + Arrays.toString(a) + " != " + Arrays.toString(b));
    }
    static void eq(String m, List<Integer> a, int[] b) { eq(m, ia(a), b); }
    static void eq(String m, double a, double b) { if (Double.compare(a, b) != 0) throw new AssertionError(m); }
    static void eq(String m, List<Integer> a, List<Integer> b) { if (!a.equals(b)) throw new AssertionError(m + ": " + a + " != " + b); }
    static void eq(String m, List<List<String>> a, List<List<String>> b) { if (!a.equals(b)) throw new AssertionError(m); }
    static void eq(String m, List<List<Integer>> a, List<List<Integer>> b) { if (!a.equals(b)) throw new AssertionError(m); }
    static void eqDeep(String m, Object a, Object b) { if (!Objects.deepEquals(a, b)) throw new AssertionError(m + ": " + a + " vs " + b); }
    static void isNull(String m, Object a) { if (a != null) throw new AssertionError(m); }
    static void isTrue(String m, boolean b) { if (!b) throw new AssertionError(m); }
    static List<Integer> il(int... xs) { return Arrays.stream(xs).boxed().toList(); }
    static int[] ia(List<Integer> xs) { return xs.stream().mapToInt(i -> i).toArray(); }
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * from typing import List
 * from collections import deque
 */

// Source imports: from typing import List
// Source imports: from collections import deque

// %% [markdown]
// ---
// ## Q1: Valid Parentheses
//
// Given a string containing just '(', ')', '{', '}', '[', ']', determine if the input string is valid.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def is_valid(s: str) -> bool:
 *  """
 *  Check if parentheses are valid.
 *  
 *  Args:
 *  s: String with brackets
 *  
 *  Returns:
 *  True if valid
 *  """
 *  # Your code here
 *  pass
 */

static boolean isValid(String s) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert is_valid("()") == True, "Test 1 failed"
 * assert is_valid("()[]{}") == True, "Test 2 failed"
 * assert is_valid("(]") == False, "Test 3 failed"
 * assert is_valid("([)]") == False, "Test 4 failed"
 * assert is_valid("{[]}") == True, "Test 5 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", isValid("()"), true);
T.eq("Test 2 failed", isValid("()[]{}"), true);
T.eq("Test 3 failed", isValid("(]"), false);
T.eq("Test 4 failed", isValid("([)]"), false);
T.eq("Test 5 failed", isValid("{[]}"), true);
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q2: Min Stack
//
// Design a stack that supports push, pop, top, and retrieving the minimum element in constant time.

// %%
/*
 * --- Original exercise specification (reference) ---
 * class MinStack:
 *  """
 *  Stack with O(1) getMin operation.
 *  """
 *  
 *  def __init__(self):
 *  # Your code here
 *  pass
 *  
 *  def push(self, val: int) -> None:
 *  pass
 *  
 *  def pop(self) -> None:
 *  pass
 *  
 *  def top(self) -> int:
 *  pass
 *  
 *  def getMin(self) -> int:
 *  pass
 */

class MinStack {
    MinStack() {
        throw new UnsupportedOperationException();
    }
    Object push(int val) {
        throw new UnsupportedOperationException();
    }
    Object pop() {
        throw new UnsupportedOperationException();
    }
    int top() {
        throw new UnsupportedOperationException();
    }
    int getMin() {
        throw new UnsupportedOperationException();
    }
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * stack = MinStack()
 * stack.push(-2)
 * stack.push(0)
 * stack.push(-3)
 * assert stack.getMin() == -3, "Test 1 failed"
 * stack.pop()
 * assert stack.top() == 0, "Test 2 failed"
 * assert stack.getMin() == -2, "Test 3 failed"
 * print("All tests passed!")
 */

var stack = MinStack();
// expr: stack.push(-2)
// expr: stack.push(0)
// expr: stack.push(-3)
// assert: assert stack.getMin() == -3, 'Test 1 failed'
// expr: stack.pop()
// assert: assert stack.top() == 0, 'Test 2 failed'
// assert: assert stack.getMin() == -2, 'Test 3 failed'
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q3: Daily Temperatures
//
// Given an array of temperatures, return an array where answer[i] is the number of days until a warmer temperature. If no future day is warmer, put 0.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def daily_temperatures(temperatures: List[int]) -> List[int]:
 *  """
 *  Find days until warmer temperature.
 *  
 *  Args:
 *  temperatures: Daily temperatures
 *  
 *  Returns:
 *  Days to wait for warmer temp
 *  """
 *  # Your code here
 *  pass
 */

static List<Integer> dailyTemperatures(List<Integer> temperatures) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert daily_temperatures([73,74,75,71,69,72,76,73]) == [1,1,4,2,1,1,0,0], "Test 1 failed"
 * assert daily_temperatures([30,40,50,60]) == [1,1,1,0], "Test 2 failed"
 * assert daily_temperatures([30,60,90]) == [1,1,0], "Test 3 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", dailyTemperatures(new int[] {73, 74, 75, 71, 69, 72, 76, 73}), new int[] {1, 1, 4, 2, 1, 1, 0, 0});
T.eq("Test 2 failed", dailyTemperatures(new int[] {30, 40, 50, 60}), new int[] {1, 1, 1, 0});
T.eq("Test 3 failed", dailyTemperatures(new int[] {30, 60, 90}), new int[] {1, 1, 0});
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q4: Evaluate Reverse Polish Notation
//
// Evaluate the value of an arithmetic expression in Reverse Polish Notation (postfix).

// %%
/*
 * --- Original exercise specification (reference) ---
 * def eval_rpn(tokens: List[str]) -> int:
 *  """
 *  Evaluate Reverse Polish Notation.
 *  
 *  Args:
 *  tokens: RPN expression
 *  
 *  Returns:
 *  Result of evaluation
 *  """
 *  # Your code here
 *  pass
 */

static int evalRpn(List<String> tokens) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert eval_rpn(["2","1","+","3","*"]) == 9, "Test 1 failed" # (2+1)*3
 * assert eval_rpn(["4","13","5","/","+"]) == 6, "Test 2 failed" # 4+(13/5)
 * assert eval_rpn(["10","6","9","3","+","-11","*","/","*","17","+","5","+"]) == 22, "Test 3 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", evalRpn(Arrays.asList("2", "1", "+", "3", "*")), 9);
T.eq("Test 2 failed", evalRpn(Arrays.asList("4", "13", "5", "/", "+")), 6);
T.eq("Test 3 failed", evalRpn(Arrays.asList("10", "6", "9", "3", "+", "-11", "*", "/", "*", "17", "+", "5", "+")), 22);
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q5: Largest Rectangle in Histogram
//
// Given an array of integers heights representing the histogram's bar heights, find the area of largest rectangle in the histogram.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def largest_rectangle_area(heights: List[int]) -> int:
 *  """
 *  Find largest rectangle in histogram.
 *  
 *  Args:
 *  heights: Bar heights
 *  
 *  Returns:
 *  Largest rectangle area
 *  """
 *  # Your code here
 *  pass
 */

static int largestRectangleArea(List<Integer> heights) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert largest_rectangle_area([2,1,5,6,2,3]) == 10, "Test 1 failed"
 * assert largest_rectangle_area([2,4]) == 4, "Test 2 failed"
 * assert largest_rectangle_area([1]) == 1, "Test 3 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", largestRectangleArea(new int[] {2, 1, 5, 6, 2, 3}), 10);
T.eq("Test 2 failed", largestRectangleArea(new int[] {2, 4}), 4);
T.eq("Test 3 failed", largestRectangleArea(new int[] {1}), 1);
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q6: Implement Queue using Stacks
//
// Implement a first in first out (FIFO) queue using only two stacks.

// %%
/*
 * --- Original exercise specification (reference) ---
 * class MyQueue:
 *  """
 *  Queue implemented with two stacks.
 *  """
 *  
 *  def __init__(self):
 *  # Your code here
 *  pass
 *  
 *  def push(self, x: int) -> None:
 *  pass
 *  
 *  def pop(self) -> int:
 *  pass
 *  
 *  def peek(self) -> int:
 *  pass
 *  
 *  def empty(self) -> bool:
 *  pass
 */

class MyQueue {
    MyQueue() {
        throw new UnsupportedOperationException();
    }
    Object push(int x) {
        throw new UnsupportedOperationException();
    }
    int pop() {
        throw new UnsupportedOperationException();
    }
    int peek() {
        throw new UnsupportedOperationException();
    }
    boolean empty() {
        throw new UnsupportedOperationException();
    }
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * q = MyQueue()
 * q.push(1)
 * q.push(2)
 * assert q.peek() == 1, "Test 1 failed"
 * assert q.pop() == 1, "Test 2 failed"
 * assert q.empty() == False, "Test 3 failed"
 * print("All tests passed!")
 */

var q = MyQueue();
// expr: q.push(1)
// expr: q.push(2)
// assert: assert q.peek() == 1, 'Test 1 failed'
// assert: assert q.pop() == 1, 'Test 2 failed'
// assert: assert q.empty() == False, 'Test 3 failed'
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q7: Sliding Window Maximum
//
// Given an array and a sliding window of size k, return the max value in each window position.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def max_sliding_window(nums: List[int], k: int) -> List[int]:
 *  """
 *  Find max in each sliding window.
 *  
 *  Args:
 *  nums: Array of integers
 *  k: Window size
 *  
 *  Returns:
 *  Max of each window
 *  """
 *  # Your code here
 *  pass
 */

static List<Integer> maxSlidingWindow(List<Integer> nums, int k) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert max_sliding_window([1,3,-1,-3,5,3,6,7], 3) == [3,3,5,5,6,7], "Test 1 failed"
 * assert max_sliding_window([1], 1) == [1], "Test 2 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", maxSlidingWindow(Arrays.asList(1, 3, -1, -3, 5, 3, 6, 7), 3), new int[] {3, 3, 5, 5, 6, 7});
T.eq("Test 2 failed", maxSlidingWindow(new int[] {1}, 1), new int[] {1});
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q8: Next Greater Element I
//
// Given two arrays nums1 and nums2 where nums1 is a subset of nums2, find the next greater element for each element in nums1.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def next_greater_element(nums1: List[int], nums2: List[int]) -> List[int]:
 *  """
 *  Find next greater element for nums1 elements in nums2.
 *  
 *  Args:
 *  nums1: Query elements
 *  nums2: Full array
 *  
 *  Returns:
 *  Next greater element for each nums1 element
 *  """
 *  # Your code here
 *  pass
 */

static List<Integer> nextGreaterElement(List<Integer> nums1, List<Integer> nums2) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert next_greater_element([4,1,2], [1,3,4,2]) == [-1,3,-1], "Test 1 failed"
 * assert next_greater_element([2,4], [1,2,3,4]) == [3,-1], "Test 2 failed"
 * print("All tests passed!")
 */

T.eqDeep("Test 1 failed", nextGreaterElement(new int[] {4, 1, 2}, new int[] {1, 3, 4, 2}), Arrays.asList(-1, 3, -1));
T.eqDeep("Test 2 failed", nextGreaterElement(new int[] {2, 4}, new int[] {1, 2, 3, 4}), Arrays.asList(3, -1));
System.out.println("All tests passed!");
