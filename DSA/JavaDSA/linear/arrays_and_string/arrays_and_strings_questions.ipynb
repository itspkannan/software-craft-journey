// %% [markdown]
// # Arrays and Strings - Practice Questions
//
// Complete each function and run the test cases to verify your solution.

// %% [markdown]
// ---
// ## Q1: Two Sum
//
// Given an array of integers `nums` and an integer `target`, return indices of the two numbers such that they add up to `target`.
//
// - Each input has exactly one solution
// - You may not use the same element twice

// %%
import java.util.*;
import java.util.stream.*;
import java.util.function.*;

/** Test helpers (assertions always checked; not dependent on -ea). */
final class T {
    static void eq(String m, int a, int b) { if (a != b) throw new AssertionError(m + ": " + a + " != " + b); }
    static void eq(String m, long a, long b) { if (a != b) throw new AssertionError(m + ": " + a + " != " + b); }
    static void eq(String m, boolean a, boolean b) { if (a != b) throw new AssertionError(m); }
    static void eq(String m, String a, String b) { if (!Objects.equals(a, b)) throw new AssertionError(m + ": " + a + " != " + b); }
    static void eq(String m, int[] a, int[] b) {
        if (!Arrays.equals(a, b)) throw new AssertionError(m + ": " + Arrays.toString(a) + " != " + Arrays.toString(b));
    }
    static void eq(String m, List<Integer> a, int[] b) { eq(m, ia(a), b); }
    static void eq(String m, double a, double b) { if (Double.compare(a, b) != 0) throw new AssertionError(m); }
    static void eq(String m, List<Integer> a, List<Integer> b) { if (!a.equals(b)) throw new AssertionError(m + ": " + a + " != " + b); }
    static void eq(String m, List<List<String>> a, List<List<String>> b) { if (!a.equals(b)) throw new AssertionError(m); }
    static void eq(String m, List<List<Integer>> a, List<List<Integer>> b) { if (!a.equals(b)) throw new AssertionError(m); }
    static void eqDeep(String m, Object a, Object b) { if (!Objects.deepEquals(a, b)) throw new AssertionError(m + ": " + a + " vs " + b); }
    static void isNull(String m, Object a) { if (a != null) throw new AssertionError(m); }
    static void isTrue(String m, boolean b) { if (!b) throw new AssertionError(m); }
    static List<Integer> il(int... xs) { return Arrays.stream(xs).boxed().toList(); }
    static int[] ia(List<Integer> xs) { return xs.stream().mapToInt(i -> i).toArray(); }
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * def two_sum(nums: list[int], target: int) -> list[int]:
 *  """
 *  Find two numbers that add up to target.
 *  
 *  Args:
 *  nums: List of integers
 *  target: Target sum
 *  
 *  Returns:
 *  List of two indices
 *  """
 *  # Your code here
 *  pass
 */

static int[] twoSum(int[] nums, int target) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert two_sum([2, 7, 11, 15], 9) == [0, 1], "Test 1 failed"
 * assert two_sum([3, 2, 4], 6) == [1, 2], "Test 2 failed"
 * assert two_sum([3, 3], 6) == [0, 1], "Test 3 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", twoSum(new int[] {2, 7, 11, 15}, 9), new int[] {0, 1});
T.eq("Test 2 failed", twoSum(new int[] {3, 2, 4}, 6), new int[] {1, 2});
T.eq("Test 3 failed", twoSum(new int[] {3, 3}, 6), new int[] {0, 1});
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q2: Valid Palindrome
//
// Given a string `s`, return `True` if it is a palindrome, considering only alphanumeric characters and ignoring cases.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def is_palindrome(s: str) -> bool:
 *  """
 *  Check if string is a palindrome (ignore non-alphanumeric and case).
 *  
 *  Args:
 *  s: Input string
 *  
 *  Returns:
 *  True if palindrome, False otherwise
 *  """
 *  # Your code here
 *  pass
 */

static boolean isPalindrome(String s) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert is_palindrome("A man, a plan, a canal: Panama") == True, "Test 1 failed"
 * assert is_palindrome("race a car") == False, "Test 2 failed"
 * assert is_palindrome(" ") == True, "Test 3 failed"
 * assert is_palindrome("Was it a car or a cat I saw?") == True, "Test 4 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", isPalindrome("A man, a plan, a canal: Panama"), true);
T.eq("Test 2 failed", isPalindrome("race a car"), false);
T.eq("Test 3 failed", isPalindrome(" "), true);
T.eq("Test 4 failed", isPalindrome("Was it a car or a cat I saw?"), true);
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q3: Best Time to Buy and Sell Stock
//
// Given an array `prices` where `prices[i]` is the price of a stock on the ith day, find the maximum profit from one transaction (buy one day, sell on a later day).
//
// Return 0 if no profit is possible.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def max_profit(prices: list[int]) -> int:
 *  """
 *  Find maximum profit from buying and selling stock once.
 *  
 *  Args:
 *  prices: List of daily stock prices
 *  
 *  Returns:
 *  Maximum profit possible
 *  """
 *  # Your code here
 *  pass
 */

static int maxProfit(int[] prices) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert max_profit([7, 1, 5, 3, 6, 4]) == 5, "Test 1 failed" # Buy at 1, sell at 6
 * assert max_profit([7, 6, 4, 3, 1]) == 0, "Test 2 failed" # No profit possible
 * assert max_profit([1, 2]) == 1, "Test 3 failed"
 * assert max_profit([2, 4, 1]) == 2, "Test 4 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", maxProfit(new int[] {7, 1, 5, 3, 6, 4}), 5);
T.eq("Test 2 failed", maxProfit(new int[] {7, 6, 4, 3, 1}), 0);
T.eq("Test 3 failed", maxProfit(new int[] {1, 2}), 1);
T.eq("Test 4 failed", maxProfit(new int[] {2, 4, 1}), 2);
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q4: Contains Duplicate
//
// Given an integer array `nums`, return `True` if any value appears at least twice.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def contains_duplicate(nums: list[int]) -> bool:
 *  """
 *  Check if array contains any duplicate.
 *  
 *  Args:
 *  nums: List of integers
 *  
 *  Returns:
 *  True if duplicates exist, False otherwise
 *  """
 *  # Your code here
 *  pass
 */

static boolean containsDuplicate(int[] nums) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert contains_duplicate([1, 2, 3, 1]) == True, "Test 1 failed"
 * assert contains_duplicate([1, 2, 3, 4]) == False, "Test 2 failed"
 * assert contains_duplicate([1, 1, 1, 3, 3, 4, 3, 2, 4, 2]) == True, "Test 3 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", containsDuplicate(new int[] {1, 2, 3, 1}), true);
T.eq("Test 2 failed", containsDuplicate(new int[] {1, 2, 3, 4}), false);
T.eq("Test 3 failed", containsDuplicate(new int[] {1, 1, 1, 3, 3, 4, 3, 2, 4, 2}), true);
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q5: Product of Array Except Self
//
// Given an integer array `nums`, return an array `answer` such that `answer[i]` is equal to the product of all elements of `nums` except `nums[i]`.
//
// **Constraint:** Solve in O(n) time without using division.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def product_except_self(nums: list[int]) -> list[int]:
 *  """
 *  Calculate product of all elements except self.
 *  
 *  Args:
 *  nums: List of integers
 *  
 *  Returns:
 *  List where each element is product of all others
 *  """
 *  # Your code here
 *  pass
 */

static int[] productExceptSelf(int[] nums) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert product_except_self([1, 2, 3, 4]) == [24, 12, 8, 6], "Test 1 failed"
 * assert product_except_self([-1, 1, 0, -3, 3]) == [0, 0, 9, 0, 0], "Test 2 failed"
 * assert product_except_self([2, 3]) == [3, 2], "Test 3 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", productExceptSelf(new int[] {1, 2, 3, 4}), new int[] {24, 12, 8, 6});
T.eq("Test 2 failed", productExceptSelf(Arrays.asList(-1, 1, 0, -3, 3)), new int[] {0, 0, 9, 0, 0});
T.eq("Test 3 failed", productExceptSelf(new int[] {2, 3}), new int[] {3, 2});
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q6: Maximum Subarray (Kadane's Algorithm)
//
// Given an integer array `nums`, find the subarray with the largest sum and return its sum.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def max_subarray(nums: list[int]) -> int:
 *  """
 *  Find the maximum sum of a contiguous subarray.
 *  
 *  Args:
 *  nums: List of integers
 *  
 *  Returns:
 *  Maximum subarray sum
 *  """
 *  # Your code here
 *  pass
 */

static int maxSubarray(int[] nums) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert max_subarray([-2, 1, -3, 4, -1, 2, 1, -5, 4]) == 6, "Test 1 failed" # [4,-1,2,1]
 * assert max_subarray([1]) == 1, "Test 2 failed"
 * assert max_subarray([5, 4, -1, 7, 8]) == 23, "Test 3 failed"
 * assert max_subarray([-1]) == -1, "Test 4 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", maxSubarray(Arrays.asList(-2, 1, -3, 4, -1, 2, 1, -5, 4)), 6);
T.eq("Test 2 failed", maxSubarray(new int[] {1}), 1);
T.eq("Test 3 failed", maxSubarray(Arrays.asList(5, 4, -1, 7, 8)), 23);
// assert: assert max_subarray([-1]) == -1, 'Test 4 failed'
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q7: Longest Substring Without Repeating Characters
//
// Given a string `s`, find the length of the longest substring without repeating characters.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def length_of_longest_substring(s: str) -> int:
 *  """
 *  Find length of longest substring without repeating characters.
 *  
 *  Args:
 *  s: Input string
 *  
 *  Returns:
 *  Length of longest substring
 *  """
 *  # Your code here
 *  pass
 */

static int lengthOfLongestSubstring(String s) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert length_of_longest_substring("abcabcbb") == 3, "Test 1 failed" # "abc"
 * assert length_of_longest_substring("bbbbb") == 1, "Test 2 failed" # "b"
 * assert length_of_longest_substring("pwwkew") == 3, "Test 3 failed" # "wke"
 * assert length_of_longest_substring("") == 0, "Test 4 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", lengthOfLongestSubstring("abcabcbb"), 3);
T.eq("Test 2 failed", lengthOfLongestSubstring("bbbbb"), 1);
T.eq("Test 3 failed", lengthOfLongestSubstring("pwwkew"), 3);
T.eq("Test 4 failed", lengthOfLongestSubstring(""), 0);
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q8: Group Anagrams
//
// Given an array of strings `strs`, group the anagrams together. An anagram is a word formed by rearranging the letters of another word.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def group_anagrams(strs: list[str]) -> list[list[str]]:
 *  """
 *  Group anagrams together.
 *  
 *  Args:
 *  strs: List of strings
 *  
 *  Returns:
 *  List of grouped anagrams
 *  """
 *  # Your code here
 *  pass
 */

static List<List<String>> groupAnagrams(List<String> strs) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * result = group_anagrams(["eat","tea","tan","ate","nat","bat"])
 * # Sort for comparison
 * result = [sorted(group) for group in result]
 * result.sort()
 * expected = [['ate', 'eat', 'tea'], ['bat'], ['nat', 'tan']]
 * assert result == expected, f"Test 1 failed: {result}"
 * 
 * assert group_anagrams([""]) == [[""]], "Test 2 failed"
 * assert group_anagrams(["a"]) == [["a"]], "Test 3 failed"
 * print("All tests passed!")
 */

var result = groupAnagrams(Arrays.asList("eat", "tea", "tan", "ate", "nat", "bat"));
// result = [sorted(group) for group in result]  → implement in Java
// expr: result.sort()
// expected = [['ate', 'eat', 'tea'], ['bat'], ['nat', 'tan']]  → implement in Java
// assert: assert result == expected, f'Test 1 failed: {result}'
T.eqDeep("Test 2 failed", groupAnagrams(Arrays.asList("")), Arrays.asList(Arrays.asList("")));
T.eqDeep("Test 3 failed", groupAnagrams(Arrays.asList("a")), Arrays.asList(Arrays.asList("a")));
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q9: 3Sum
//
// Given an integer array `nums`, return all unique triplets `[nums[i], nums[j], nums[k]]` such that `i != j != k` and `nums[i] + nums[j] + nums[k] == 0`.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def three_sum(nums: list[int]) -> list[list[int]]:
 *  """
 *  Find all unique triplets that sum to zero.
 *  
 *  Args:
 *  nums: List of integers
 *  
 *  Returns:
 *  List of triplets
 *  """
 *  # Your code here
 *  pass
 */

static List<Integer> threeSum(int[] nums) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * result = three_sum([-1, 0, 1, 2, -1, -4])
 * result = [sorted(t) for t in result]
 * result.sort()
 * assert result == [[-1, -1, 2], [-1, 0, 1]], f"Test 1 failed: {result}"
 * 
 * assert three_sum([0, 1, 1]) == [], "Test 2 failed"
 * assert three_sum([0, 0, 0]) == [[0, 0, 0]], "Test 3 failed"
 * print("All tests passed!")
 */

var result = threeSum(Arrays.asList(-1, 0, 1, 2, -1, -4));
// result = [sorted(t) for t in result]  → implement in Java
// expr: result.sort()
// assert: assert result == [[-1, -1, 2], [-1, 0, 1]], f'Test 1 failed: {result}'
T.eqDeep("Test 2 failed", threeSum(new int[] {0, 1, 1}), Arrays.asList());
T.eqDeep("Test 3 failed", threeSum(new int[] {0, 0, 0}), Arrays.asList(new int[] {0, 0, 0}));
System.out.println("All tests passed!");

// %% [markdown]
// ---
// ## Q10: Container With Most Water
//
// Given an array `height` of length n, find two lines that together with the x-axis form a container that holds the most water.
//
// Return the maximum amount of water a container can store.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def max_area(height: list[int]) -> int:
 *  """
 *  Find maximum water container area.
 *  
 *  Args:
 *  height: List of line heights
 *  
 *  Returns:
 *  Maximum area
 *  """
 *  # Your code here
 *  pass
 */

static int maxArea(int[] height) {
    throw new UnsupportedOperationException();
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert max_area([1, 8, 6, 2, 5, 4, 8, 3, 7]) == 49, "Test 1 failed"
 * assert max_area([1, 1]) == 1, "Test 2 failed"
 * assert max_area([4, 3, 2, 1, 4]) == 16, "Test 3 failed"
 * print("All tests passed!")
 */

T.eq("Test 1 failed", maxArea(new int[] {1, 8, 6, 2, 5, 4, 8, 3, 7}), 49);
T.eq("Test 2 failed", maxArea(new int[] {1, 1}), 1);
T.eq("Test 3 failed", maxArea(new int[] {4, 3, 2, 1, 4}), 16);
System.out.println("All tests passed!");
