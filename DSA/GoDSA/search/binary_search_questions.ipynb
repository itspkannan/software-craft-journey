// %% [markdown]
// # Binary Search - Practice Questions
//
// Complete each function and run the test cases to verify your solution.

// %%
import (
	"fmt"
	"reflect"
)

func eq(msg string, a, b interface{}) {
	if !reflect.DeepEqual(a, b) {
		panic(fmt.Sprintf("%s: %#v != %#v", msg, a, b))
	}
}

func isNil(msg string, v interface{}) {
	if v == nil {
		return
	}
	rv := reflect.ValueOf(v)
	switch rv.Kind() {
	case reflect.Ptr, reflect.Map, reflect.Slice, reflect.Interface, reflect.Chan, reflect.Func:
		if rv.IsNil() {
			return
		}
	}
	panic(msg)
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * from typing import List
 */

// Source imports: from typing import List

// %% [markdown]
// ---
// ## Q1: Binary Search
//
// Given a sorted array of integers and a target, return the index of target. If not found, return -1.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def search(nums: List[int], target: int) -> int:
 *  """
 *  Binary search for target.
 *  
 *  Args:
 *  nums: Sorted array
 *  target: Value to find
 *  
 *  Returns:
 *  Index of target, or -1
 *  """
 *  # Your code here
 *  pass
 */

func Search(nums []int, target int) int {
	panic("TODO")
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert search([-1,0,3,5,9,12], 9) == 4, "Test 1 failed"
 * assert search([-1,0,3,5,9,12], 2) == -1, "Test 2 failed"
 * assert search([5], 5) == 0, "Test 3 failed"
 * print("All tests passed!")
 */

eq("Test 1 failed", Search([]interface{}{-1, 0, 3, 5, 9, 12}, 9), 4)
eq("Test 2 failed", Search([]interface{}{-1, 0, 3, 5, 9, 12}, 2), -1)
eq("Test 3 failed", Search([]int{5}, 5), 0)
fmt.Println("All tests passed!")

// %% [markdown]
// ---
// ## Q2: Search Insert Position
//
// Given a sorted array and a target, return the index if found. If not, return the index where it would be inserted.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def search_insert(nums: List[int], target: int) -> int:
 *  """
 *  Find insert position for target.
 *  
 *  Args:
 *  nums: Sorted array
 *  target: Value to find/insert
 *  
 *  Returns:
 *  Index of target or insert position
 *  """
 *  # Your code here
 *  pass
 */

func SearchInsert(nums []int, target int) int {
	panic("TODO")
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert search_insert([1,3,5,6], 5) == 2, "Test 1 failed"
 * assert search_insert([1,3,5,6], 2) == 1, "Test 2 failed"
 * assert search_insert([1,3,5,6], 7) == 4, "Test 3 failed"
 * assert search_insert([1,3,5,6], 0) == 0, "Test 4 failed"
 * print("All tests passed!")
 */

eq("Test 1 failed", SearchInsert([]int{1, 3, 5, 6}, 5), 2)
eq("Test 2 failed", SearchInsert([]int{1, 3, 5, 6}, 2), 1)
eq("Test 3 failed", SearchInsert([]int{1, 3, 5, 6}, 7), 4)
eq("Test 4 failed", SearchInsert([]int{1, 3, 5, 6}, 0), 0)
fmt.Println("All tests passed!")

// %% [markdown]
// ---
// ## Q3: Find First and Last Position
//
// Given a sorted array of integers, find the starting and ending position of a given target value. Return [-1, -1] if not found.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def search_range(nums: List[int], target: int) -> List[int]:
 *  """
 *  Find first and last position of target.
 *  
 *  Args:
 *  nums: Sorted array
 *  target: Value to find
 *  
 *  Returns:
 *  [first_index, last_index] or [-1, -1]
 *  """
 *  # Your code here
 *  pass
 */

func SearchRange(nums []int, target int) []int {
	panic("TODO")
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert search_range([5,7,7,8,8,10], 8) == [3, 4], "Test 1 failed"
 * assert search_range([5,7,7,8,8,10], 6) == [-1, -1], "Test 2 failed"
 * assert search_range([], 0) == [-1, -1], "Test 3 failed"
 * print("All tests passed!")
 */

eq("Test 1 failed", SearchRange([]int{5, 7, 7, 8, 8, 10}, 8), []int{3, 4})
eq("Test 2 failed", SearchRange([]int{5, 7, 7, 8, 8, 10}, 6), []interface{}{-1, -1})
eq("Test 3 failed", SearchRange([]int{}, 0), []interface{}{-1, -1})
fmt.Println("All tests passed!")

// %% [markdown]
// ---
// ## Q4: Search in Rotated Sorted Array
//
// Given a rotated sorted array (e.g., [4,5,6,7,0,1,2]), search for a target value.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def search_rotated(nums: List[int], target: int) -> int:
 *  """
 *  Search in rotated sorted array.
 *  
 *  Args:
 *  nums: Rotated sorted array
 *  target: Value to find
 *  
 *  Returns:
 *  Index of target, or -1
 *  """
 *  # Your code here
 *  pass
 */

func SearchRotated(nums []int, target int) int {
	panic("TODO")
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert search_rotated([4,5,6,7,0,1,2], 0) == 4, "Test 1 failed"
 * assert search_rotated([4,5,6,7,0,1,2], 3) == -1, "Test 2 failed"
 * assert search_rotated([1], 0) == -1, "Test 3 failed"
 * assert search_rotated([3,1], 1) == 1, "Test 4 failed"
 * print("All tests passed!")
 */

eq("Test 1 failed", SearchRotated([]int{4, 5, 6, 7, 0, 1, 2}, 0), 4)
eq("Test 2 failed", SearchRotated([]int{4, 5, 6, 7, 0, 1, 2}, 3), -1)
eq("Test 3 failed", SearchRotated([]int{1}, 0), -1)
eq("Test 4 failed", SearchRotated([]int{3, 1}, 1), 1)
fmt.Println("All tests passed!")

// %% [markdown]
// ---
// ## Q5: Find Minimum in Rotated Sorted Array
//
// Given a rotated sorted array of unique elements, find the minimum element.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def find_min(nums: List[int]) -> int:
 *  """
 *  Find minimum in rotated sorted array.
 *  
 *  Args:
 *  nums: Rotated sorted array
 *  
 *  Returns:
 *  Minimum element
 *  """
 *  # Your code here
 *  pass
 */

func FindMin(nums []int) int {
	panic("TODO")
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert find_min([3,4,5,1,2]) == 1, "Test 1 failed"
 * assert find_min([4,5,6,7,0,1,2]) == 0, "Test 2 failed"
 * assert find_min([11,13,15,17]) == 11, "Test 3 failed"
 * print("All tests passed!")
 */

eq("Test 1 failed", FindMin([]int{3, 4, 5, 1, 2}), 1)
eq("Test 2 failed", FindMin([]int{4, 5, 6, 7, 0, 1, 2}), 0)
eq("Test 3 failed", FindMin([]int{11, 13, 15, 17}), 11)
fmt.Println("All tests passed!")

// %% [markdown]
// ---
// ## Q6: Find Peak Element
//
// A peak element is greater than its neighbors. Find a peak element and return its index. Array may contain multiple peaks.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def find_peak_element(nums: List[int]) -> int:
 *  """
 *  Find any peak element index.
 *  
 *  Args:
 *  nums: Array of integers
 *  
 *  Returns:
 *  Index of a peak element
 *  """
 *  # Your code here
 *  pass
 */

func FindPeakElement(nums []int) int {
	panic("TODO")
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * result = find_peak_element([1,2,3,1])
 * assert result == 2, f"Test 1 failed: got {result}"
 * 
 * result = find_peak_element([1,2,1,3,5,6,4])
 * assert result in [1, 5], f"Test 2 failed: got {result}"
 * print("All tests passed!")
 */

result := FindPeakElement([]int{1, 2, 3, 1})
// assert: assert result == 2, f'Test 1 failed: got {result}'
result = FindPeakElement([]int{1, 2, 1, 3, 5, 6, 4})
// assert: assert result in [1, 5], f'Test 2 failed: got {result}'
fmt.Println("All tests passed!")

// %% [markdown]
// ---
// ## Q7: Koko Eating Bananas
//
// Koko can eat at most k bananas per hour. Given piles of bananas and h hours, find the minimum k such that she can eat all bananas within h hours.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def min_eating_speed(piles: List[int], h: int) -> int:
 *  """
 *  Find minimum eating speed to finish in h hours.
 *  
 *  Args:
 *  piles: Array of banana pile sizes
 *  h: Hours available
 *  
 *  Returns:
 *  Minimum eating speed
 *  """
 *  # Your code here
 *  pass
 */

func MinEatingSpeed(piles []int, h int) int {
	panic("TODO")
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert min_eating_speed([3,6,7,11], 8) == 4, "Test 1 failed"
 * assert min_eating_speed([30,11,23,4,20], 5) == 30, "Test 2 failed"
 * assert min_eating_speed([30,11,23,4,20], 6) == 23, "Test 3 failed"
 * print("All tests passed!")
 */

eq("Test 1 failed", MinEatingSpeed([]int{3, 6, 7, 11}, 8), 4)
eq("Test 2 failed", MinEatingSpeed([]int{30, 11, 23, 4, 20}, 5), 30)
eq("Test 3 failed", MinEatingSpeed([]int{30, 11, 23, 4, 20}, 6), 23)
fmt.Println("All tests passed!")

// %% [markdown]
// ---
// ## Q8: Search a 2D Matrix
//
// Given an m x n matrix where each row is sorted and the first element of each row is greater than the last element of the previous row, search for a target.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def search_matrix(matrix: List[List[int]], target: int) -> bool:
 *  """
 *  Search for target in 2D matrix.
 *  
 *  Args:
 *  matrix: 2D sorted matrix
 *  target: Value to find
 *  
 *  Returns:
 *  True if found
 *  """
 *  # Your code here
 *  pass
 */

func SearchMatrix(matrix [][]int, target int) bool {
	panic("TODO")
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * matrix = [[1,3,5,7],[10,11,16,20],[23,30,34,60]]
 * assert search_matrix(matrix, 3) == True, "Test 1 failed"
 * assert search_matrix(matrix, 13) == False, "Test 2 failed"
 * print("All tests passed!")
 */

// matrix = [[1, 3, 5, 7], [10, 11, 16, 20], [23, 30, 34, 60]]  → implement in Go
eq("Test 1 failed", SearchMatrix(matrix, 3), true)
eq("Test 2 failed", SearchMatrix(matrix, 13), false)
fmt.Println("All tests passed!")
