// %% [markdown]
// # Linked Lists - Practice Questions
//
// Complete each function and run the test cases to verify your solution.

// %%
import (
	"fmt"
	"reflect"
	"strings"
	"unicode"
)

func mapHasIntInt(m map[int]int, k int) bool {
	_, ok := m[k]
	return ok
}

func mapHasByteInt(m map[byte]int, k byte) bool {
	_, ok := m[k]
	return ok
}

func eq(msg string, a, b interface{}) {
	if !reflect.DeepEqual(a, b) {
		panic(fmt.Sprintf("%s: %#v != %#v", msg, a, b))
	}
}

func isNil(msg string, v interface{}) {
	if v == nil {
		return
	}
	rv := reflect.ValueOf(v)
	switch rv.Kind() {
	case reflect.Ptr, reflect.Map, reflect.Slice, reflect.Interface, reflect.Chan, reflect.Func:
		if rv.IsNil() {
			return
		}
	}
	panic(msg)
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * from typing import Optional, List
 * 
 * class ListNode:
 *  def __init__(self, val=0, next=None):
 *  self.val = val
 *  self.next = next
 *  
 *  def __repr__(self):
 *  vals = []
 *  node = self
 *  while node:
 *  vals.append(str(node.val))
 *  node = node.next
 *  return ' -> '.join(vals)
 * 
 * def build_list(vals: list) -> Optional[ListNode]:
 *  """Build linked list from array."""
 *  if not vals:
 *  return None
 *  head = ListNode(vals[0])
 *  curr = head
 *  for val in vals[1:]:
 *  curr.next = ListNode(val)
 *  curr = curr.next
 *  return head
 * 
 * def list_to_array(head: ListNode) -> list:
 *  """Convert linked list to array for testing."""
 *  result = []
 *  while head:
 *  result.append(head.val)
 *  head = head.next
 *  return result
 */

// Source imports: from typing import Optional, List
type ListNode struct {
}

func BuildList(vals []interface{}) *ListNode {
	// TODO: implement from specification above
}
func ListToArray(head ListNode) []interface{} {
	// TODO: implement from specification above
}

// %% [markdown]
// ---
// ## Q1: Reverse Linked List
//
// Given the head of a singly linked list, reverse the list and return the reversed list.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def reverse_list(head: Optional[ListNode]) -> Optional[ListNode]:
 *  """
 *  Reverse the linked list.
 *  
 *  Args:
 *  head: Head of linked list
 *  
 *  Returns:
 *  Head of reversed list
 *  """
 *  # Your code here
 *  pass
 */

func ReverseList(head *ListNode) *ListNode {
	panic("TODO")
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert list_to_array(reverse_list(build_list([1,2,3,4,5]))) == [5,4,3,2,1], "Test 1 failed"
 * assert list_to_array(reverse_list(build_list([1,2]))) == [2,1], "Test 2 failed"
 * assert reverse_list(None) is None, "Test 3 failed"
 * print("All tests passed!")
 */

eq("Test 1 failed", ListToArray(ReverseList(BuildList([]int{1, 2, 3, 4, 5}))), []int{5, 4, 3, 2, 1})
eq("Test 2 failed", ListToArray(ReverseList(BuildList([]int{1, 2}))), []int{2, 1})
isNil("Test 3 failed", ReverseList(nil))
fmt.Println("All tests passed!")

// %% [markdown]
// ---
// ## Q2: Merge Two Sorted Lists
//
// Merge two sorted linked lists and return it as a sorted list.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def merge_two_lists(list1: Optional[ListNode], list2: Optional[ListNode]) -> Optional[ListNode]:
 *  """
 *  Merge two sorted linked lists.
 *  
 *  Args:
 *  list1: Head of first sorted list
 *  list2: Head of second sorted list
 *  
 *  Returns:
 *  Head of merged sorted list
 *  """
 *  # Your code here
 *  pass
 */

func MergeTwoLists(list1 *ListNode, list2 *ListNode) *ListNode {
	panic("TODO")
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * l1 = build_list([1,2,4])
 * l2 = build_list([1,3,4])
 * assert list_to_array(merge_two_lists(l1, l2)) == [1,1,2,3,4,4], "Test 1 failed"
 * 
 * assert merge_two_lists(None, None) is None, "Test 2 failed"
 * assert list_to_array(merge_two_lists(None, build_list([0]))) == [0], "Test 3 failed"
 * print("All tests passed!")
 */

l1 := BuildList([]int{1, 2, 4})
l2 := BuildList([]int{1, 3, 4})
eq("Test 1 failed", ListToArray(MergeTwoLists(l1, l2)), []int{1, 1, 2, 3, 4, 4})
isNil("Test 2 failed", MergeTwoLists(nil, nil))
eq("Test 3 failed", ListToArray(MergeTwoLists(nil, BuildList([]int{0}))), []int{0})
fmt.Println("All tests passed!")

// %% [markdown]
// ---
// ## Q3: Linked List Cycle
//
// Given head of a linked list, determine if the linked list has a cycle.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def has_cycle(head: Optional[ListNode]) -> bool:
 *  """
 *  Detect if linked list has a cycle.
 *  
 *  Args:
 *  head: Head of linked list
 *  
 *  Returns:
 *  True if cycle exists
 *  """
 *  # Your code here
 *  pass
 */

func HasCycle(head *ListNode) bool {
	panic("TODO")
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * # List without cycle
 * assert has_cycle(build_list([1,2,3,4])) == False, "Test 1 failed"
 * 
 * # List with cycle
 * head = build_list([3,2,0,-4])
 * head.next.next.next.next = head.next # -4 -> 2
 * assert has_cycle(head) == True, "Test 2 failed"
 * 
 * assert has_cycle(None) == False, "Test 3 failed"
 * print("All tests passed!")
 */

eq("Test 1 failed", HasCycle(BuildList([]int{1, 2, 3, 4})), false)
head := BuildList([]interface{}{3, 2, 0, -4})
// head.next.next.next.next = head.next  → implement in Go
eq("Test 2 failed", HasCycle(head), true)
eq("Test 3 failed", HasCycle(nil), false)
fmt.Println("All tests passed!")

// %% [markdown]
// ---
// ## Q4: Middle of the Linked List
//
// Given the head of a linked list, return the middle node. If two middle nodes, return the second middle node.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def middle_node(head: Optional[ListNode]) -> Optional[ListNode]:
 *  """
 *  Find middle node of linked list.
 *  
 *  Args:
 *  head: Head of linked list
 *  
 *  Returns:
 *  Middle node
 *  """
 *  # Your code here
 *  pass
 */

func MiddleNode(head *ListNode) *ListNode {
	panic("TODO")
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert middle_node(build_list([1,2,3,4,5])).val == 3, "Test 1 failed"
 * assert middle_node(build_list([1,2,3,4,5,6])).val == 4, "Test 2 failed" # Second middle
 * assert middle_node(build_list([1])).val == 1, "Test 3 failed"
 * print("All tests passed!")
 */

// assert: assert middle_node(build_list([1, 2, 3, 4, 5])).val == 3, 'Test 1 failed'
// assert: assert middle_node(build_list([1, 2, 3, 4, 5, 6])).val == 4, 'Test 2 failed'
// assert: assert middle_node(build_list([1])).val == 1, 'Test 3 failed'
fmt.Println("All tests passed!")

// %% [markdown]
// ---
// ## Q5: Remove Nth Node From End of List
//
// Given the head of a linked list, remove the nth node from the end and return its head.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def remove_nth_from_end(head: Optional[ListNode], n: int) -> Optional[ListNode]:
 *  """
 *  Remove nth node from end.
 *  
 *  Args:
 *  head: Head of linked list
 *  n: Position from end (1-indexed)
 *  
 *  Returns:
 *  Head of modified list
 *  """
 *  # Your code here
 *  pass
 */

func RemoveNthFromEnd(head *ListNode, n int) *ListNode {
	panic("TODO")
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert list_to_array(remove_nth_from_end(build_list([1,2,3,4,5]), 2)) == [1,2,3,5], "Test 1 failed"
 * assert list_to_array(remove_nth_from_end(build_list([1]), 1)) == [], "Test 2 failed"
 * assert list_to_array(remove_nth_from_end(build_list([1,2]), 1)) == [1], "Test 3 failed"
 * print("All tests passed!")
 */

eq("Test 1 failed", ListToArray(RemoveNthFromEnd(BuildList([]int{1, 2, 3, 4, 5}), 2)), []int{1, 2, 3, 5})
eq("Test 2 failed", ListToArray(RemoveNthFromEnd(BuildList([]int{1}), 1)), []int{})
eq("Test 3 failed", ListToArray(RemoveNthFromEnd(BuildList([]int{1, 2}), 1)), []int{1})
fmt.Println("All tests passed!")

// %% [markdown]
// ---
// ## Q6: Palindrome Linked List
//
// Given the head of a singly linked list, return true if it is a palindrome.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def is_palindrome(head: Optional[ListNode]) -> bool:
 *  """
 *  Check if linked list is palindrome.
 *  
 *  Args:
 *  head: Head of linked list
 *  
 *  Returns:
 *  True if palindrome
 *  """
 *  # Your code here
 *  pass
 */

func IsPalindrome(head *ListNode) bool {
	panic("TODO")
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * assert is_palindrome(build_list([1,2,2,1])) == True, "Test 1 failed"
 * assert is_palindrome(build_list([1,2])) == False, "Test 2 failed"
 * assert is_palindrome(build_list([1])) == True, "Test 3 failed"
 * assert is_palindrome(build_list([1,2,3,2,1])) == True, "Test 4 failed"
 * print("All tests passed!")
 */

eq("Test 1 failed", IsPalindrome(BuildList([]int{1, 2, 2, 1})), true)
eq("Test 2 failed", IsPalindrome(BuildList([]int{1, 2})), false)
eq("Test 3 failed", IsPalindrome(BuildList([]int{1})), true)
eq("Test 4 failed", IsPalindrome(BuildList([]int{1, 2, 3, 2, 1})), true)
fmt.Println("All tests passed!")

// %% [markdown]
// ---
// ## Q7: Reorder List
//
// Given a list L0 → L1 → ... → Ln-1 → Ln, reorder it to: L0 → Ln → L1 → Ln-1 → L2 → Ln-2 → ...

// %%
/*
 * --- Original exercise specification (reference) ---
 * def reorder_list(head: Optional[ListNode]) -> None:
 *  """
 *  Reorder list in-place.
 *  
 *  Args:
 *  head: Head of linked list
 *  """
 *  # Your code here
 *  pass
 */

func ReorderList(head *ListNode) {
	panic("TODO")
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * head = build_list([1,2,3,4])
 * reorder_list(head)
 * assert list_to_array(head) == [1,4,2,3], f"Test 1 failed: {list_to_array(head)}"
 * 
 * head = build_list([1,2,3,4,5])
 * reorder_list(head)
 * assert list_to_array(head) == [1,5,2,4,3], f"Test 2 failed: {list_to_array(head)}"
 * print("All tests passed!")
 */

head := BuildList([]int{1, 2, 3, 4})
// expr: reorder_list(head)
eq("assert failed", ListToArray(head), []int{1, 4, 2, 3})
head = BuildList([]int{1, 2, 3, 4, 5})
// expr: reorder_list(head)
eq("assert failed", ListToArray(head), []int{1, 5, 2, 4, 3})
fmt.Println("All tests passed!")

// %% [markdown]
// ---
// ## Q8: Add Two Numbers
//
// You are given two non-empty linked lists representing two non-negative integers. Digits are stored in reverse order. Add the two numbers and return the sum as a linked list.

// %%
/*
 * --- Original exercise specification (reference) ---
 * def add_two_numbers(l1: Optional[ListNode], l2: Optional[ListNode]) -> Optional[ListNode]:
 *  """
 *  Add two numbers represented as linked lists.
 *  
 *  Args:
 *  l1: First number (reverse order)
 *  l2: Second number (reverse order)
 *  
 *  Returns:
 *  Sum as linked list (reverse order)
 *  """
 *  # Your code here
 *  pass
 */

func AddTwoNumbers(l1 *ListNode, l2 *ListNode) *ListNode {
	panic("TODO")
}

// %%
/*
 * --- Original exercise specification (reference) ---
 * # Test Cases
 * # 342 + 465 = 807
 * l1 = build_list([2,4,3])
 * l2 = build_list([5,6,4])
 * assert list_to_array(add_two_numbers(l1, l2)) == [7,0,8], "Test 1 failed"
 * 
 * assert list_to_array(add_two_numbers(build_list([0]), build_list([0]))) == [0], "Test 2 failed"
 * 
 * # 99 + 1 = 100
 * l1 = build_list([9,9])
 * l2 = build_list([1])
 * assert list_to_array(add_two_numbers(l1, l2)) == [0,0,1], "Test 3 failed"
 * print("All tests passed!")
 */

l1 := BuildList([]int{2, 4, 3})
l2 := BuildList([]int{5, 6, 4})
eq("Test 1 failed", ListToArray(AddTwoNumbers(l1, l2)), []int{7, 0, 8})
eq("Test 2 failed", ListToArray(AddTwoNumbers(BuildList([]int{0}), BuildList([]int{0}))), []int{0})
l1 = BuildList([]int{9, 9})
l2 = BuildList([]int{1})
eq("Test 3 failed", ListToArray(AddTwoNumbers(l1, l2)), []int{0, 0, 1})
fmt.Println("All tests passed!")
